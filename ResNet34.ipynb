# %% [markdown]
# <a href="https://colab.research.google.com/github/anpendyal/Convolutional-Neural-Networks-in-Breast-Cancer-Identification-Research-10th-Grade-/blob/main/ResNet34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#give program access to google drive where the dataset is
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#install library to get resnet34 because it is not included in keras
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-3cudfrag
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-3cudfrag
#   Running command git submodule update --init --recursive -q
# Collecting keras_applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.5 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.21.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.5.2)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-py3-none-any.whl size=20046 sha256=f718639ae67496b4148390b64996488e933f73d1a9c87a1375e81b5c5166a30b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aww86ol4/wheels/0b/96/56/27b17c903efc647c51e4f364bfc20aa67f8d3dccad63c4fb4e
# Successfully built image-classifiers
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8

# %%
# for tensorflow keras
from classification_models.tfkeras import Classifiers
Classifiers.models_names()
# Out:
# ['resnet18',
#  'resnet34',
#  'resnet50',
#  'resnet101',
#  'resnet152',
#  'seresnet18',
#  'seresnet34',
#  'seresnet50',
#  'seresnet101',
#  'seresnet152',
#  'seresnext50',
#  'seresnext101',
#  'senet154',
#  'resnet50v2',
#  'resnet101v2',
#  'resnet152v2',
#  'resnext50',
#  'resnext101',
#  'vgg16',
#  'vgg19',
#  'densenet121',
#  'densenet169',
#  'densenet201',
#  'inceptionresnetv2',
#  'inceptionv3',
#  'xception',
#  'nasnetlarge',
#  'nasnetmobile',
#  'mobilenet',
#  'mobilenetv2']

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from tensorflow.keras.layers import MaxPooling2D

# %%
#specify paths to dataset in google drive
import tensorflow as tf

train_path = "/content/drive/MyDrive/SSI 2021/Train Set"
val_path = "/content/drive/MyDrive/SSI 2021/Validation Set"
test_path = "/content/drive/MyDrive/SSI 2021/Test Set"

# %%
#download ResNet34 and set up model
ResNet34, preprocess_input = Classifiers.get('resnet34')
resnet34 = ResNet34(include_top = False, input_shape=(224, 224, 3), weights='imagenet')
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 4s 0us/step
# 85532672/85521592 [==============================] - 4s 0us/step

# %%
resnet34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 28, 28, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 30, 30, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 28, 28, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 28, 28, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 30, 30, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 14, 14, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 14, 14, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 14, 14, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 16, 16, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 7, 7, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 7, 7, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 7, 7, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 7, 7, 512)    0           ['bn1[0][0]']
#
# ==================================================================================================
# Total params: 21,302,473
# Trainable params: 21,287,107
# Non-trainable params: 15,366
# __________________________________________________________________________________________________

# %%
for layer in resnet34.layers:
  layer.trainable = False

# %%
from glob import glob
#training set
folders = glob("/content/drive/MyDrive/SSI 2021/Train Set/*")
len(folders)
# Out:
# 2

# %%
x = Flatten()(resnet34.output)

# %%
prediction = Dense(len(folders), activation = "sigmoid")(x)

#create a model object
model = Model(inputs = resnet34.input, outputs = prediction)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 28, 28, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 30, 30, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 28, 28, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 28, 28, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 30, 30, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 14, 14, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 14, 14, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 14, 14, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 16, 16, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 7, 7, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 7, 7, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 7, 7, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 7, 7, 512)    0           ['bn1[0][0]']
#
#  flatten (Flatten)              (None, 25088)        0           ['relu1[0][0]']
#
#  dense (Dense)                  (None, 2)            50178       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 21,352,651
# Trainable params: 50,178
# Non-trainable params: 21,302,473
# __________________________________________________________________________________________________

# %%
#binary crossentropy because the model is classifying the image as having cancer or not
#optimizer as adam because it is widely used
#metrics to use in calculation (precision and recall used to calculate f1 score)
model.compile(
    loss = "binary_crossentropy",
    optimizer = "adam",
    metrics = [
               "accuracy",
                tf.keras.metrics.BinaryAccuracy(),
                tf.keras.metrics.AUC(from_logits=True),
                tf.keras.metrics.Precision(),
                tf.keras.metrics.Recall(),
                tf.keras.metrics.TruePositives(),
                tf.keras.metrics.TrueNegatives(),
                tf.keras.metrics.FalsePositives(),
                tf.keras.metrics.FalseNegatives()
               ]
)

# %%
#use image data generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#image augmentation -- come back to later
#train_datagen = ImageDataGenerator(rescale = 1./255,
#                                   shear_range = 0.2,
#                                   zoom_range = 0.2,
#                                   horizontal_flip = True)

#rescale rgb values from 0-255 to 0-1
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
#same target size as initialized for images
training_set = train_datagen.flow_from_directory("/content/drive/MyDrive/SSI 2021/Train Set",
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = "categorical")
# Out:
# Found 21607 images belonging to 2 classes.

# %%
validation_set = train_datagen.flow_from_directory("/content/drive/MyDrive/SSI 2021/Validation Set",
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = "categorical")
# Out:
# Found 977 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory("/content/drive/MyDrive/SSI 2021/Test Set",
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = "categorical")
# Out:
# Found 957 images belonging to 2 classes.

# %%
from keras.callbacks import EarlyStopping

#fit the model
#early stopping for epochs

#https://keras.io/api/callbacks/early_stopping/
#https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/ 
#use early stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 5)

history = model.fit(
    training_set,
    validation_data = validation_set,
    epochs = 50,
    #steps_per_epoch = len(training_set),
    #validation_steps = len(validation_set),
    callbacks = [early_stopping]
)

#print number of epochs 
len(history.history['loss'])
# Out:
# Epoch 1/50
# 676/676 [==============================] - 3757s 6s/step - loss: 0.6858 - accuracy: 0.6181 - binary_accuracy: 0.6182 - auc: 0.6626 - precision: 0.6184 - recall: 0.6174 - true_positives: 13340.0000 - true_negatives: 13375.0000 - false_positives: 8232.0000 - false_negatives: 8267.0000 - val_loss: 0.8382 - val_accuracy: 0.4882 - val_binary_accuracy: 0.4882 - val_auc: 0.4949 - val_precision: 0.4882 - val_recall: 0.4882 - val_true_positives: 477.0000 - val_true_negatives: 477.0000 - val_false_positives: 500.0000 - val_false_negatives: 500.0000
# Epoch 2/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.6286 - accuracy: 0.6649 - binary_accuracy: 0.6648 - auc: 0.7234 - precision: 0.6647 - recall: 0.6651 - true_positives: 14371.0000 - true_negatives: 14359.0000 - false_positives: 7248.0000 - false_negatives: 7236.0000 - val_loss: 0.8114 - val_accuracy: 0.5292 - val_binary_accuracy: 0.5292 - val_auc: 0.5442 - val_precision: 0.5291 - val_recall: 0.5312 - val_true_positives: 519.0000 - val_true_negatives: 515.0000 - val_false_positives: 462.0000 - val_false_negatives: 458.0000
# Epoch 3/50
# 676/676 [==============================] - 56s 83ms/step - loss: 0.6012 - accuracy: 0.6820 - binary_accuracy: 0.6819 - auc: 0.7479 - precision: 0.6820 - recall: 0.6818 - true_positives: 14731.0000 - true_negatives: 14738.0000 - false_positives: 6869.0000 - false_negatives: 6876.0000 - val_loss: 0.7639 - val_accuracy: 0.5589 - val_binary_accuracy: 0.5594 - val_auc: 0.5815 - val_precision: 0.5592 - val_recall: 0.5609 - val_true_positives: 548.0000 - val_true_negatives: 545.0000 - val_false_positives: 432.0000 - val_false_negatives: 429.0000
# Epoch 4/50
# 676/676 [==============================] - 55s 81ms/step - loss: 0.6097 - accuracy: 0.6831 - binary_accuracy: 0.6833 - auc: 0.7479 - precision: 0.6833 - recall: 0.6833 - true_positives: 14763.0000 - true_negatives: 14765.0000 - false_positives: 6842.0000 - false_negatives: 6844.0000 - val_loss: 1.0843 - val_accuracy: 0.5148 - val_binary_accuracy: 0.5143 - val_auc: 0.5592 - val_precision: 0.5143 - val_recall: 0.5148 - val_true_positives: 503.0000 - val_true_negatives: 502.0000 - val_false_positives: 475.0000 - val_false_negatives: 474.0000
# Epoch 5/50
# 676/676 [==============================] - 55s 81ms/step - loss: 0.6068 - accuracy: 0.6912 - binary_accuracy: 0.6910 - auc: 0.7553 - precision: 0.6910 - recall: 0.6910 - true_positives: 14930.0000 - true_negatives: 14931.0000 - false_positives: 6676.0000 - false_negatives: 6677.0000 - val_loss: 0.7933 - val_accuracy: 0.5783 - val_binary_accuracy: 0.5788 - val_auc: 0.5997 - val_precision: 0.5789 - val_recall: 0.5783 - val_true_positives: 565.0000 - val_true_negatives: 566.0000 - val_false_positives: 411.0000 - val_false_negatives: 412.0000
# Epoch 6/50
# 676/676 [==============================] - 55s 81ms/step - loss: 0.5877 - accuracy: 0.7021 - binary_accuracy: 0.7022 - auc: 0.7689 - precision: 0.7021 - recall: 0.7024 - true_positives: 15176.0000 - true_negatives: 15168.0000 - false_positives: 6439.0000 - false_negatives: 6431.0000 - val_loss: 0.8793 - val_accuracy: 0.5589 - val_binary_accuracy: 0.5599 - val_auc: 0.5949 - val_precision: 0.5600 - val_recall: 0.5589 - val_true_positives: 546.0000 - val_true_negatives: 548.0000 - val_false_positives: 429.0000 - val_false_negatives: 431.0000
# Epoch 7/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.5962 - accuracy: 0.7020 - binary_accuracy: 0.7021 - auc: 0.7671 - precision: 0.7021 - recall: 0.7021 - true_positives: 15171.0000 - true_negatives: 15169.0000 - false_positives: 6438.0000 - false_negatives: 6436.0000 - val_loss: 0.7615 - val_accuracy: 0.6018 - val_binary_accuracy: 0.6018 - val_auc: 0.6309 - val_precision: 0.6018 - val_recall: 0.6018 - val_true_positives: 588.0000 - val_true_negatives: 588.0000 - val_false_positives: 389.0000 - val_false_negatives: 389.0000
# Epoch 8/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.5795 - accuracy: 0.7145 - binary_accuracy: 0.7145 - auc: 0.7804 - precision: 0.7145 - recall: 0.7145 - true_positives: 15439.0000 - true_negatives: 15439.0000 - false_positives: 6168.0000 - false_negatives: 6168.0000 - val_loss: 0.8070 - val_accuracy: 0.5855 - val_binary_accuracy: 0.5855 - val_auc: 0.6190 - val_precision: 0.5855 - val_recall: 0.5855 - val_true_positives: 572.0000 - val_true_negatives: 572.0000 - val_false_positives: 405.0000 - val_false_negatives: 405.0000
# Epoch 9/50
# 676/676 [==============================] - 56s 83ms/step - loss: 0.5846 - accuracy: 0.7089 - binary_accuracy: 0.7090 - auc: 0.7764 - precision: 0.7089 - recall: 0.7091 - true_positives: 15322.0000 - true_negatives: 15316.0000 - false_positives: 6291.0000 - false_negatives: 6285.0000 - val_loss: 0.7236 - val_accuracy: 0.6182 - val_binary_accuracy: 0.6177 - val_auc: 0.6519 - val_precision: 0.6178 - val_recall: 0.6172 - val_true_positives: 603.0000 - val_true_negatives: 604.0000 - val_false_positives: 373.0000 - val_false_negatives: 374.0000
# Epoch 10/50
# 676/676 [==============================] - 56s 83ms/step - loss: 0.5659 - accuracy: 0.7144 - binary_accuracy: 0.7147 - auc: 0.7884 - precision: 0.7146 - recall: 0.7147 - true_positives: 15443.0000 - true_negatives: 15440.0000 - false_positives: 6167.0000 - false_negatives: 6164.0000 - val_loss: 0.7207 - val_accuracy: 0.6254 - val_binary_accuracy: 0.6249 - val_auc: 0.6564 - val_precision: 0.6250 - val_recall: 0.6244 - val_true_positives: 610.0000 - val_true_negatives: 611.0000 - val_false_positives: 366.0000 - val_false_negatives: 367.0000
# Epoch 11/50
# 676/676 [==============================] - 56s 82ms/step - loss: 0.5728 - accuracy: 0.7153 - binary_accuracy: 0.7154 - auc: 0.7858 - precision: 0.7155 - recall: 0.7154 - true_positives: 15457.0000 - true_negatives: 15460.0000 - false_positives: 6147.0000 - false_negatives: 6150.0000 - val_loss: 0.7234 - val_accuracy: 0.6264 - val_binary_accuracy: 0.6269 - val_auc: 0.6583 - val_precision: 0.6268 - val_recall: 0.6274 - val_true_positives: 613.0000 - val_true_negatives: 612.0000 - val_false_positives: 365.0000 - val_false_negatives: 364.0000
# Epoch 12/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.5819 - accuracy: 0.7135 - binary_accuracy: 0.7134 - auc: 0.7804 - precision: 0.7134 - recall: 0.7136 - true_positives: 15418.0000 - true_negatives: 15413.0000 - false_positives: 6194.0000 - false_negatives: 6189.0000 - val_loss: 0.7037 - val_accuracy: 0.6141 - val_binary_accuracy: 0.6141 - val_auc: 0.6647 - val_precision: 0.6139 - val_recall: 0.6151 - val_true_positives: 601.0000 - val_true_negatives: 599.0000 - val_false_positives: 378.0000 - val_false_negatives: 376.0000
# Epoch 13/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.5598 - accuracy: 0.7234 - binary_accuracy: 0.7235 - auc: 0.7945 - precision: 0.7235 - recall: 0.7237 - true_positives: 15636.0000 - true_negatives: 15630.0000 - false_positives: 5977.0000 - false_negatives: 5971.0000 - val_loss: 0.8015 - val_accuracy: 0.5977 - val_binary_accuracy: 0.5977 - val_auc: 0.6389 - val_precision: 0.5977 - val_recall: 0.5977 - val_true_positives: 584.0000 - val_true_negatives: 584.0000 - val_false_positives: 393.0000 - val_false_negatives: 393.0000
# Epoch 14/50
# 676/676 [==============================] - 56s 82ms/step - loss: 0.5645 - accuracy: 0.7239 - binary_accuracy: 0.7240 - auc: 0.7922 - precision: 0.7240 - recall: 0.7240 - true_positives: 15643.0000 - true_negatives: 15645.0000 - false_positives: 5962.0000 - false_negatives: 5964.0000 - val_loss: 0.7324 - val_accuracy: 0.6203 - val_binary_accuracy: 0.6203 - val_auc: 0.6592 - val_precision: 0.6203 - val_recall: 0.6203 - val_true_positives: 606.0000 - val_true_negatives: 606.0000 - val_false_positives: 371.0000 - val_false_negatives: 371.0000
# Epoch 15/50
# 676/676 [==============================] - 56s 83ms/step - loss: 0.5667 - accuracy: 0.7206 - binary_accuracy: 0.7205 - auc: 0.7909 - precision: 0.7205 - recall: 0.7206 - true_positives: 15569.0000 - true_negatives: 15568.0000 - false_positives: 6039.0000 - false_negatives: 6038.0000 - val_loss: 0.9293 - val_accuracy: 0.5701 - val_binary_accuracy: 0.5701 - val_auc: 0.6160 - val_precision: 0.5701 - val_recall: 0.5701 - val_true_positives: 557.0000 - val_true_negatives: 557.0000 - val_false_positives: 420.0000 - val_false_negatives: 420.0000
# Epoch 16/50
# 676/676 [==============================] - 55s 82ms/step - loss: 0.5593 - accuracy: 0.7269 - binary_accuracy: 0.7268 - auc: 0.7968 - precision: 0.7269 - recall: 0.7266 - true_positives: 15699.0000 - true_negatives: 15710.0000 - false_positives: 5897.0000 - false_negatives: 5908.0000 - val_loss: 0.9070 - val_accuracy: 0.5773 - val_binary_accuracy: 0.5763 - val_auc: 0.6228 - val_precision: 0.5763 - val_recall: 0.5763 - val_true_positives: 563.0000 - val_true_negatives: 563.0000 - val_false_positives: 414.0000 - val_false_negatives: 414.0000
# Epoch 17/50
# 676/676 [==============================] - 55s 81ms/step - loss: 0.5665 - accuracy: 0.7239 - binary_accuracy: 0.7240 - auc: 0.7925 - precision: 0.7240 - recall: 0.7241 - true_positives: 15645.0000 - true_negatives: 15643.0000 - false_positives: 5964.0000 - false_negatives: 5962.0000 - val_loss: 0.9106 - val_accuracy: 0.5783 - val_binary_accuracy: 0.5783 - val_auc: 0.6261 - val_precision: 0.5783 - val_recall: 0.5783 - val_true_positives: 565.0000 - val_true_negatives: 565.0000 - val_false_positives: 412.0000 - val_false_negatives: 412.0000
# Epoch 17: early stopping
# 17

# %%
#evalute model with test set
from sklearn.metrics import roc_curve, auc
model.evaluate(test_set, verbose=1)
# Out:
# 30/30 [==============================] - 282s 10s/step - loss: 0.8113 - accuracy: 0.6050 - binary_accuracy: 0.6050 - auc: 0.6900 - precision: 0.6050 - recall: 0.6050 - true_positives: 579.0000 - true_negatives: 579.0000 - false_positives: 378.0000 - false_negatives: 378.0000
# [0.8113417625427246,
#  0.6050156950950623,
#  0.6050156950950623,
#  0.6900308132171631,
#  0.6050156950950623,
#  0.6050156950950623,
#  579.0,
#  579.0,
#  378.0,
#  378.0]

# %%
#plot loss
import matplotlib.pyplot as plt
plt.plot(history.history["loss"], label = "Train loss")
plt.plot(history.history["val_loss"], label = "Validation loss")
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss")

# %%
#plot accuracy
plt.plot(history.history["accuracy"], label = "Train accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation accuracy")
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
plt.savefig("AccVal_acc")
